# %%
import pandas as pd
import numpy as np

# %%
dy = pd.read_csv('combined_discovery_yield.csv')
dy = dy[dy.Variable!="pchembl"]
dy
# Out:
#      testing batch  Total Ideal Compounds  Low Error Count  Discovery Yield  \
# 0                1                   21.0             14.0         0.666667
# 1                2                   37.0             23.0         0.621622
# 2                3                   24.0              8.0         0.333333
# 3                4                   43.0             18.0         0.418605
# 4                5                   44.0             23.0         0.522727
# ..             ...                    ...              ...              ...
# 337              6                   80.0             35.0         0.437500
# 338              7                   94.0             44.0         0.468085
# 339              8                   80.0             40.0         0.500000
# 340              9                   79.0             40.0         0.506329
# 341             10                   72.0             35.0         0.486111
#
#      Standardized Discovery Yield            Target Variable Method  \
# 0                        2.539683  target_CHEMBL240     logp     RF
# 1                        1.344047  target_CHEMBL240     logp     RF
# 2                        1.111111  target_CHEMBL240     logp     RF
# 3                        0.778799  target_CHEMBL240     logp     RF
# 4                        0.950413  target_CHEMBL240     logp     RF
# ..                            ...               ...      ...    ...
# 337                      0.612500  target_CHEMBL279      NaN    MLP
# 338                      0.557718  target_CHEMBL279      NaN    MLP
# 339                      0.700000  target_CHEMBL279      NaN    MLP
# 340                      0.717834  target_CHEMBL279      NaN    MLP
# 341                      0.756173  target_CHEMBL279      NaN    MLP
#
#            evalt
# 0     sorted_fcv
# 1     sorted_fcv
# 2     sorted_fcv
# 3     sorted_fcv
# 4     sorted_fcv
# ..           ...
# 337  scaffold_CV
# 338  scaffold_CV
# 339  scaffold_CV
# 340  scaffold_CV
# 341  scaffold_CV
#
# [342 rows x 9 columns]

# %%
# Group by and calculate mean and standard deviation
grouped = dy.groupby(["Target", "Method", "evalt"])["Discovery Yield"].agg(['mean', 'std']).reset_index()

# Combine mean and standard deviation into a single string
grouped["mean_std"] = grouped.apply(lambda row: f"{row['mean']:.2f} ± {row['std']:.2f}", axis=1)

# Drop the separate mean and std columns
grouped = grouped.drop(columns=["mean", "std"])

# Rename the column for clarity
dy = grouped.rename(columns={"mean_std": "Discovery Yield (mean ± std)"})
dy
# Out:
#               Target   Method         evalt Discovery Yield (mean ± std)
# 0   target_CHEMBL240      MLP            cv                  0.70 ± 0.11
# 1   target_CHEMBL240      MLP   scaffold_CV                  0.57 ± 0.07
# 2   target_CHEMBL240      MLP    sorted_fcv                  0.62 ± 0.12
# 3   target_CHEMBL240      MLP  unsorted_fcv                  0.63 ± 0.12
# 4   target_CHEMBL240       RF            cv                  0.74 ± 0.06
# 5   target_CHEMBL240       RF   scaffold_CV                  0.59 ± 0.14
# 6   target_CHEMBL240       RF    sorted_fcv                  0.52 ± 0.14
# 7   target_CHEMBL240       RF  unsorted_fcv                  0.65 ± 0.10
# 8   target_CHEMBL240  xgboost            cv                  0.71 ± 0.10
# 9   target_CHEMBL240  xgboost   scaffold_CV                  0.58 ± 0.10
# 10  target_CHEMBL240  xgboost    sorted_fcv                  0.46 ± 0.11
# 11  target_CHEMBL240  xgboost  unsorted_fcv                  0.65 ± 0.07
# 12  target_CHEMBL260      MLP            cv                  0.65 ± 0.05
# 13  target_CHEMBL260      MLP   scaffold_CV                  0.54 ± 0.07
# 14  target_CHEMBL260      MLP    sorted_fcv                  0.47 ± 0.06
# 15  target_CHEMBL260      MLP  unsorted_fcv                  0.57 ± 0.10
# 16  target_CHEMBL260       RF            cv                  0.74 ± 0.04
# 17  target_CHEMBL260       RF   scaffold_CV                  0.66 ± 0.08
# 18  target_CHEMBL260       RF    sorted_fcv                  0.62 ± 0.06
# 19  target_CHEMBL260       RF  unsorted_fcv                  0.68 ± 0.04
# 20  target_CHEMBL260  xgboost            cv                  0.73 ± 0.04
# 21  target_CHEMBL260  xgboost   scaffold_CV                  0.60 ± 0.08
# 22  target_CHEMBL260  xgboost    sorted_fcv                  0.60 ± 0.07
# 23  target_CHEMBL260  xgboost  unsorted_fcv                  0.67 ± 0.06
# 24  target_CHEMBL279      MLP            cv                  0.59 ± 0.03
# 25  target_CHEMBL279      MLP   scaffold_CV                  0.44 ± 0.08
# 26  target_CHEMBL279      MLP    sorted_fcv                  0.39 ± 0.06
# 27  target_CHEMBL279      MLP  unsorted_fcv                  0.49 ± 0.13
# 28  target_CHEMBL279       RF            cv                  0.67 ± 0.05
# 29  target_CHEMBL279       RF   scaffold_CV                  0.50 ± 0.10
# 30  target_CHEMBL279       RF    sorted_fcv                  0.56 ± 0.06
# 31  target_CHEMBL279       RF  unsorted_fcv                  0.59 ± 0.07
# 32  target_CHEMBL279  xgboost            cv                  0.59 ± 0.07
# 33  target_CHEMBL279  xgboost   scaffold_CV                  0.47 ± 0.11
# 34  target_CHEMBL279  xgboost    sorted_fcv                  0.53 ± 0.06
# 35  target_CHEMBL279  xgboost  unsorted_fcv                  0.54 ± 0.06

# %%
ne = pd.read_csv('combined_novelty_error.csv')
ne = ne.replace({"CV": "cv"}) 
# Group by and calculate mean and standard deviation
grouped = ne.groupby(["Target", "Method", "evalt"])["Novelty Error"].agg(['mean', 'std']).reset_index()

# Combine mean and standard deviation into a single string
grouped["mean_std"] = grouped.apply(lambda row: f"{row['mean']:.2f} ± {row['std']:.2f}", axis=1)

# Drop the separate mean and std columns
grouped = grouped.drop(columns=["mean", "std"])

# Rename the column for clarity
ne = grouped.rename(columns={"mean_std": "Novelty Error (mean ± std)"})
ne
# Out:
#               Target   Method         evalt Novelty Error (mean ± std)
# 0   target_CHEMBL240      MLP            cv                1.28 ± 0.34
# 1   target_CHEMBL240      MLP   scaffold_CV                1.07 ± 0.59
# 2   target_CHEMBL240      MLP    sorted_fcv                1.20 ± 0.45
# 3   target_CHEMBL240      MLP  unsorted_fcv                1.03 ± 0.39
# 4   target_CHEMBL240       RF            cv                0.74 ± 0.51
# 5   target_CHEMBL240       RF   scaffold_CV                0.82 ± 0.80
# 6   target_CHEMBL240       RF    sorted_fcv                0.77 ± 0.32
# 7   target_CHEMBL240       RF  unsorted_fcv                0.63 ± 0.20
# 8   target_CHEMBL240  xgboost            cv                0.72 ± 0.49
# 9   target_CHEMBL240  xgboost   scaffold_CV                0.80 ± 0.82
# 10  target_CHEMBL240  xgboost    sorted_fcv                0.76 ± 0.25
# 11  target_CHEMBL240  xgboost  unsorted_fcv                0.59 ± 0.23
# 12  target_CHEMBL260      MLP            cv                0.67 ± 0.66
# 13  target_CHEMBL260      MLP   scaffold_CV                1.04 ± 0.45
# 14  target_CHEMBL260      MLP    sorted_fcv                1.20 ± 0.50
# 15  target_CHEMBL260      MLP  unsorted_fcv                1.02 ± 0.52
# 16  target_CHEMBL260       RF            cv                0.76 ± 0.39
# 17  target_CHEMBL260       RF   scaffold_CV                0.88 ± 0.22
# 18  target_CHEMBL260       RF    sorted_fcv                0.89 ± 0.16
# 19  target_CHEMBL260       RF  unsorted_fcv                0.81 ± 0.34
# 20  target_CHEMBL260  xgboost            cv                0.79 ± 0.50
# 21  target_CHEMBL260  xgboost   scaffold_CV                0.95 ± 0.13
# 22  target_CHEMBL260  xgboost    sorted_fcv                0.92 ± 0.20
# 23  target_CHEMBL260  xgboost  unsorted_fcv                0.87 ± 0.30
# 24  target_CHEMBL279      MLP            cv                1.04 ± 0.59
# 25  target_CHEMBL279      MLP   scaffold_CV                0.87 ± 0.34
# 26  target_CHEMBL279      MLP    sorted_fcv                1.33 ± 0.17
# 27  target_CHEMBL279      MLP  unsorted_fcv                1.08 ± 0.34
# 28  target_CHEMBL279       RF            cv                0.91 ± 0.35
# 29  target_CHEMBL279       RF   scaffold_CV                0.71 ± 0.23
# 30  target_CHEMBL279       RF    sorted_fcv                0.85 ± 0.15
# 31  target_CHEMBL279       RF  unsorted_fcv                0.92 ± 0.33
# 32  target_CHEMBL279  xgboost            cv                0.95 ± 0.28
# 33  target_CHEMBL279  xgboost   scaffold_CV                0.71 ± 0.21
# 34  target_CHEMBL279  xgboost    sorted_fcv                0.86 ± 0.16
# 35  target_CHEMBL279  xgboost  unsorted_fcv                0.87 ± 0.24

# %%
cm = pd.read_csv('combined_metrics.csv')
cm = cm[cm.Sorting_Var!="pchembl"]
cm
# Out:
#                Target Sorting_Var Method  Testing Batch      RMSE        R2  \
# 0    target_CHEMBL240        logp     RF              1  0.539731  0.336317
# 1    target_CHEMBL240        logp     RF              2  0.567511  0.014182
# 2    target_CHEMBL240        logp     RF              3  1.089359 -0.077649
# 3    target_CHEMBL240        logp     RF              4  0.707705  0.518710
# 4    target_CHEMBL240        logp     RF              5  0.758903  0.613842
# ..                ...         ...    ...            ...       ...       ...
# 418  target_CHEMBL279        None    MLP              6  0.909121  0.461547
# 419  target_CHEMBL279        None    MLP              7  0.890862  0.354422
# 420  target_CHEMBL279        None    MLP              8  0.879394  0.318483
# 421  target_CHEMBL279        None    MLP              9  0.818693  0.550499
# 422  target_CHEMBL279        None    MLP             10  1.049085  0.039878
#
#            evalt
# 0     sorted_fcv
# 1     sorted_fcv
# 2     sorted_fcv
# 3     sorted_fcv
# 4     sorted_fcv
# ..           ...
# 418  scaffold_CV
# 419  scaffold_CV
# 420  scaffold_CV
# 421  scaffold_CV
# 422  scaffold_CV
#
# [342 rows x 7 columns]

# %%
# Group by and calculate mean and standard deviation
grouped = cm.groupby(["Target", "Method", "evalt"])["R2"].agg(['mean', 'std']).reset_index()

# Combine mean and standard deviation into a single string
grouped["mean_std"] = grouped.apply(lambda row: f"{row['mean']:.2f} ± {row['std']:.2f}", axis=1)

# Drop the separate mean and std columns
grouped = grouped.drop(columns=["mean", "std"])

# Rename the column for clarity
r2 = grouped.rename(columns={"mean_std": "R2 (mean ± std)"})
r2
# Out:
#               Target   Method         evalt R2 (mean ± std)
# 0   target_CHEMBL240      MLP            cv     0.58 ± 0.10
# 1   target_CHEMBL240      MLP   scaffold_CV     0.08 ± 0.58
# 2   target_CHEMBL240      MLP    sorted_fcv    -0.11 ± 0.95
# 3   target_CHEMBL240      MLP  unsorted_fcv    -0.09 ± 0.95
# 4   target_CHEMBL240       RF            cv     0.70 ± 0.07
# 5   target_CHEMBL240       RF   scaffold_CV     0.41 ± 0.31
# 6   target_CHEMBL240       RF    sorted_fcv     0.35 ± 0.46
# 7   target_CHEMBL240       RF  unsorted_fcv     0.48 ± 0.24
# 8   target_CHEMBL240  xgboost            cv     0.70 ± 0.09
# 9   target_CHEMBL240  xgboost   scaffold_CV     0.38 ± 0.27
# 10  target_CHEMBL240  xgboost    sorted_fcv     0.33 ± 0.44
# 11  target_CHEMBL240  xgboost  unsorted_fcv     0.50 ± 0.22
# 12  target_CHEMBL260      MLP            cv     0.66 ± 0.07
# 13  target_CHEMBL260      MLP   scaffold_CV     0.39 ± 0.41
# 14  target_CHEMBL260      MLP    sorted_fcv     0.33 ± 0.28
# 15  target_CHEMBL260      MLP  unsorted_fcv     0.57 ± 0.23
# 16  target_CHEMBL260       RF            cv     0.76 ± 0.04
# 17  target_CHEMBL260       RF   scaffold_CV     0.62 ± 0.18
# 18  target_CHEMBL260       RF    sorted_fcv     0.55 ± 0.10
# 19  target_CHEMBL260       RF  unsorted_fcv     0.67 ± 0.08
# 20  target_CHEMBL260  xgboost            cv     0.74 ± 0.05
# 21  target_CHEMBL260  xgboost   scaffold_CV     0.53 ± 0.26
# 22  target_CHEMBL260  xgboost    sorted_fcv     0.52 ± 0.12
# 23  target_CHEMBL260  xgboost  unsorted_fcv     0.66 ± 0.09
# 24  target_CHEMBL279      MLP            cv     0.53 ± 0.06
# 25  target_CHEMBL279      MLP   scaffold_CV     0.27 ± 0.21
# 26  target_CHEMBL279      MLP    sorted_fcv     0.04 ± 0.35
# 27  target_CHEMBL279      MLP  unsorted_fcv     0.40 ± 0.24
# 28  target_CHEMBL279       RF            cv     0.66 ± 0.04
# 29  target_CHEMBL279       RF   scaffold_CV     0.46 ± 0.19
# 30  target_CHEMBL279       RF    sorted_fcv     0.44 ± 0.11
# 31  target_CHEMBL279       RF  unsorted_fcv     0.58 ± 0.09
# 32  target_CHEMBL279  xgboost            cv     0.62 ± 0.03
# 33  target_CHEMBL279  xgboost   scaffold_CV     0.41 ± 0.26
# 34  target_CHEMBL279  xgboost    sorted_fcv     0.42 ± 0.11
# 35  target_CHEMBL279  xgboost  unsorted_fcv     0.56 ± 0.07

# %%
# Group by and calculate mean and standard deviation
grouped = cm.groupby(["Target", "Method", "evalt"])["RMSE"].agg(['mean', 'std']).reset_index()

# Combine mean and standard deviation into a single string
grouped["mean_std"] = grouped.apply(lambda row: f"{row['mean']:.2f} ± {row['std']:.2f}", axis=1)

# Drop the separate mean and std columns
grouped = grouped.drop(columns=["mean", "std"])

# Rename the column for clarity
RMSE = grouped.rename(columns={"mean_std": "RMSE (mean ± std)"})
RMSE
# Out:
#               Target   Method         evalt RMSE (mean ± std)
# 0   target_CHEMBL240      MLP            cv       0.66 ± 0.06
# 1   target_CHEMBL240      MLP   scaffold_CV       0.81 ± 0.21
# 2   target_CHEMBL240      MLP    sorted_fcv       0.91 ± 0.30
# 3   target_CHEMBL240      MLP  unsorted_fcv       0.92 ± 0.25
# 4   target_CHEMBL240       RF            cv       0.55 ± 0.07
# 5   target_CHEMBL240       RF   scaffold_CV       0.69 ± 0.35
# 6   target_CHEMBL240       RF    sorted_fcv       0.72 ± 0.20
# 7   target_CHEMBL240       RF  unsorted_fcv       0.68 ± 0.07
# 8   target_CHEMBL240  xgboost            cv       0.55 ± 0.07
# 9   target_CHEMBL240  xgboost   scaffold_CV       0.71 ± 0.33
# 10  target_CHEMBL240  xgboost    sorted_fcv       0.73 ± 0.19
# 11  target_CHEMBL240  xgboost  unsorted_fcv       0.67 ± 0.08
# 12  target_CHEMBL260      MLP            cv       0.67 ± 0.05
# 13  target_CHEMBL260      MLP   scaffold_CV       0.83 ± 0.12
# 14  target_CHEMBL260      MLP    sorted_fcv       0.91 ± 0.20
# 15  target_CHEMBL260      MLP  unsorted_fcv       0.75 ± 0.17
# 16  target_CHEMBL260       RF            cv       0.57 ± 0.05
# 17  target_CHEMBL260       RF   scaffold_CV       0.67 ± 0.08
# 18  target_CHEMBL260       RF    sorted_fcv       0.76 ± 0.11
# 19  target_CHEMBL260       RF  unsorted_fcv       0.66 ± 0.08
# 20  target_CHEMBL260  xgboost            cv       0.59 ± 0.06
# 21  target_CHEMBL260  xgboost   scaffold_CV       0.73 ± 0.10
# 22  target_CHEMBL260  xgboost    sorted_fcv       0.79 ± 0.12
# 23  target_CHEMBL260  xgboost  unsorted_fcv       0.68 ± 0.09
# 24  target_CHEMBL279      MLP            cv       0.74 ± 0.06
# 25  target_CHEMBL279      MLP   scaffold_CV       0.89 ± 0.11
# 26  target_CHEMBL279      MLP    sorted_fcv       1.02 ± 0.13
# 27  target_CHEMBL279      MLP  unsorted_fcv       0.83 ± 0.15
# 28  target_CHEMBL279       RF            cv       0.63 ± 0.05
# 29  target_CHEMBL279       RF   scaffold_CV       0.77 ± 0.08
# 30  target_CHEMBL279       RF    sorted_fcv       0.79 ± 0.06
# 31  target_CHEMBL279       RF  unsorted_fcv       0.70 ± 0.07
# 32  target_CHEMBL279  xgboost            cv       0.67 ± 0.04
# 33  target_CHEMBL279  xgboost   scaffold_CV       0.79 ± 0.10
# 34  target_CHEMBL279  xgboost    sorted_fcv       0.80 ± 0.05
# 35  target_CHEMBL279  xgboost  unsorted_fcv       0.72 ± 0.06

# %%
combined_mean = pd.merge(r2, RMSE)
combined_mean = pd.merge(combined_mean, ne)
combined_mean = pd.merge(combined_mean, dy)

# %%
combined_mean
# Out:
#               Target   Method         evalt R2 (mean ± std) RMSE (mean ± std)  \
# 0   target_CHEMBL240      MLP            cv     0.58 ± 0.10       0.66 ± 0.06
# 1   target_CHEMBL240      MLP   scaffold_CV     0.08 ± 0.58       0.81 ± 0.21
# 2   target_CHEMBL240      MLP    sorted_fcv    -0.11 ± 0.95       0.91 ± 0.30
# 3   target_CHEMBL240      MLP  unsorted_fcv    -0.09 ± 0.95       0.92 ± 0.25
# 4   target_CHEMBL240       RF            cv     0.70 ± 0.07       0.55 ± 0.07
# 5   target_CHEMBL240       RF   scaffold_CV     0.41 ± 0.31       0.69 ± 0.35
# 6   target_CHEMBL240       RF    sorted_fcv     0.35 ± 0.46       0.72 ± 0.20
# 7   target_CHEMBL240       RF  unsorted_fcv     0.48 ± 0.24       0.68 ± 0.07
# 8   target_CHEMBL240  xgboost            cv     0.70 ± 0.09       0.55 ± 0.07
# 9   target_CHEMBL240  xgboost   scaffold_CV     0.38 ± 0.27       0.71 ± 0.33
# 10  target_CHEMBL240  xgboost    sorted_fcv     0.33 ± 0.44       0.73 ± 0.19
# 11  target_CHEMBL240  xgboost  unsorted_fcv     0.50 ± 0.22       0.67 ± 0.08
# 12  target_CHEMBL260      MLP            cv     0.66 ± 0.07       0.67 ± 0.05
# 13  target_CHEMBL260      MLP   scaffold_CV     0.39 ± 0.41       0.83 ± 0.12
# 14  target_CHEMBL260      MLP    sorted_fcv     0.33 ± 0.28       0.91 ± 0.20
# 15  target_CHEMBL260      MLP  unsorted_fcv     0.57 ± 0.23       0.75 ± 0.17
# 16  target_CHEMBL260       RF            cv     0.76 ± 0.04       0.57 ± 0.05
# 17  target_CHEMBL260       RF   scaffold_CV     0.62 ± 0.18       0.67 ± 0.08
# 18  target_CHEMBL260       RF    sorted_fcv     0.55 ± 0.10       0.76 ± 0.11
# 19  target_CHEMBL260       RF  unsorted_fcv     0.67 ± 0.08       0.66 ± 0.08
# 20  target_CHEMBL260  xgboost            cv     0.74 ± 0.05       0.59 ± 0.06
# 21  target_CHEMBL260  xgboost   scaffold_CV     0.53 ± 0.26       0.73 ± 0.10
# 22  target_CHEMBL260  xgboost    sorted_fcv     0.52 ± 0.12       0.79 ± 0.12
# 23  target_CHEMBL260  xgboost  unsorted_fcv     0.66 ± 0.09       0.68 ± 0.09
# 24  target_CHEMBL279      MLP            cv     0.53 ± 0.06       0.74 ± 0.06
# 25  target_CHEMBL279      MLP   scaffold_CV     0.27 ± 0.21       0.89 ± 0.11
# 26  target_CHEMBL279      MLP    sorted_fcv     0.04 ± 0.35       1.02 ± 0.13
# 27  target_CHEMBL279      MLP  unsorted_fcv     0.40 ± 0.24       0.83 ± 0.15
# 28  target_CHEMBL279       RF            cv     0.66 ± 0.04       0.63 ± 0.05
# 29  target_CHEMBL279       RF   scaffold_CV     0.46 ± 0.19       0.77 ± 0.08
# 30  target_CHEMBL279       RF    sorted_fcv     0.44 ± 0.11       0.79 ± 0.06
# 31  target_CHEMBL279       RF  unsorted_fcv     0.58 ± 0.09       0.70 ± 0.07
# 32  target_CHEMBL279  xgboost            cv     0.62 ± 0.03       0.67 ± 0.04
# 33  target_CHEMBL279  xgboost   scaffold_CV     0.41 ± 0.26       0.79 ± 0.10
# 34  target_CHEMBL279  xgboost    sorted_fcv     0.42 ± 0.11       0.80 ± 0.05
# 35  target_CHEMBL279  xgboost  unsorted_fcv     0.56 ± 0.07       0.72 ± 0.06
#
#    Novelty Error (mean ± std) Discovery Yield (mean ± std)
# 0                 1.28 ± 0.34                  0.70 ± 0.11
# 1                 1.07 ± 0.59                  0.57 ± 0.07
# 2                 1.20 ± 0.45                  0.62 ± 0.12
# 3                 1.03 ± 0.39                  0.63 ± 0.12
# 4                 0.74 ± 0.51                  0.74 ± 0.06
# 5                 0.82 ± 0.80                  0.59 ± 0.14
# 6                 0.77 ± 0.32                  0.52 ± 0.14
# 7                 0.63 ± 0.20                  0.65 ± 0.10
# 8                 0.72 ± 0.49                  0.71 ± 0.10
# 9                 0.80 ± 0.82                  0.58 ± 0.10
# 10                0.76 ± 0.25                  0.46 ± 0.11
# 11                0.59 ± 0.23                  0.65 ± 0.07
# 12                0.67 ± 0.66                  0.65 ± 0.05
# 13                1.04 ± 0.45                  0.54 ± 0.07
# 14                1.20 ± 0.50                  0.47 ± 0.06
# 15                1.02 ± 0.52                  0.57 ± 0.10
# 16                0.76 ± 0.39                  0.74 ± 0.04
# 17                0.88 ± 0.22                  0.66 ± 0.08
# 18                0.89 ± 0.16                  0.62 ± 0.06
# 19                0.81 ± 0.34                  0.68 ± 0.04
# 20                0.79 ± 0.50                  0.73 ± 0.04
# 21                0.95 ± 0.13                  0.60 ± 0.08
# 22                0.92 ± 0.20                  0.60 ± 0.07
# 23                0.87 ± 0.30                  0.67 ± 0.06
# 24                1.04 ± 0.59                  0.59 ± 0.03
# 25                0.87 ± 0.34                  0.44 ± 0.08
# 26                1.33 ± 0.17                  0.39 ± 0.06
# 27                1.08 ± 0.34                  0.49 ± 0.13
# 28                0.91 ± 0.35                  0.67 ± 0.05
# 29                0.71 ± 0.23                  0.50 ± 0.10
# 30                0.85 ± 0.15                  0.56 ± 0.06
# 31                0.92 ± 0.33                  0.59 ± 0.07
# 32                0.95 ± 0.28                  0.59 ± 0.07
# 33                0.71 ± 0.21                  0.47 ± 0.11
# 34                0.86 ± 0.16                  0.53 ± 0.06
# 35                0.87 ± 0.24                  0.54 ± 0.06

# %%
combined_mean.to_csv("combined_mean_std.csv", index=False)
