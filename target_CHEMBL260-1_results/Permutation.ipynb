# %%
import pandas as pd
df=pd.read_csv("../data/target_CHEMBL260-1.IC50_ready.csv.gz",compression="gzip")
df
# Out:
#                                     Standardized_SMILES  pchembl_value
# 0     C#CCOCCn1c(SC)nc(-c2ccc(F)cc2)c1-c1cc[nH]c(=NC...           6.18
# 1     C#CCOCCn1c(SCc2ccc([S+](C)[O-])cc2)nc(-c2ccc(F...           5.30
# 2     C#Cc1ccc(-c2nc(-c3cc[nH]c(=O)c3)c(-c3ccc(F)cc3...           5.03
# 3     C#Cc1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccnc(SC)n3)[n...           4.09
# 4         C#Cc1ccn2c(-c3ccnc(SC)n3)c(-c3ccc(F)cc3)nc2n1           5.60
# ...                                                 ...            ...
# 1440  [O-][n+]1ccc2c(-c3ccccc3Cl)cc(OC3CCNCC3)nc2c1-...           9.34
# 1441  [O-][n+]1ccc2c(-c3ccccc3Cl)ccnc2c1-c1c(Cl)cccc1Cl           7.43
# 1442         c1ccc(-c2ncoc2-c2ccc3nnc(-c4ccno4)n3c2)cc1           6.54
# 1443            c1ccc(-c2ncoc2-c2ccc3nnc(C4CC4)n3c2)cc1           7.33
# 1444           c1ccc(-c2ncoc2-c2ccc3nnc(C4CCC4)n3c2)cc1           7.78
#
# [1445 rows x 2 columns]

# %%
df=df.sample(frac=1)

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=False)

def calculate_molwt(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return Descriptors.MolWt(mol)
    return None

def calculate_logp(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return Descriptors.MolLogP(mol)
    return None
def calculate_QED(smiles):
    mol=Chem.MolFromSmiles(smiles)
    if mol:
        return Chem.QED.default(mol)
    return

df['MolWt'] =df['Standardized_SMILES'].apply(calculate_molwt)
df['LogP'] = df['Standardized_SMILES'].apply(calculate_logp)
df['QED'] = df['Standardized_SMILES'].apply(calculate_QED)
# Out:
# INFO: Pandarallel will run on 14 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %%
df
# Out:
#                                     Standardized_SMILES  pchembl_value  \
# 118        CC(C)c1nnc2ccc(-c3c[nH]nc3-c3cc(F)ccc3F)cn12           8.55
# 42    CC(=O)Nc1cnccc1CCOc1ccc(NC(=O)N=c2cc(C(C)(C)C)...           8.10
# 752   Cc1ccc(-n2[nH]c(C(C)(C)C)cc2=NC(=O)Nc2ccc(OCCN...           7.81
# 1404  O=c1ncc2c(-c3ccccc3Cl)cc(C(O)N3CCNCC3)cc2n1-c1...           8.82
# 1017  Cn1c(-c2cn(C(C)(C)C(=O)O)nn2)nc(-c2ccc(F)cc2)c...           5.83
# ...                                                 ...            ...
# 236   CCN(C(=O)c1csc2ccccc12)c1cc[nH]c(=NC(C)c2ccccc...           6.73
# 537   COc1cc2[nH]cnc(=Nc3cc(NC(=O)c4ccnc(N5CCOCC5)c4...           7.30
# 336   CN1CCC(c2cc(-c3ccc(F)cc3Cl)c3c(c2)N(c2c(Cl)ccc...           9.30
# 873   Cc1ccc(C(=O)Nc2cccc(C(F)(F)F)c2C)cc1-c1ccc2[nH...           8.05
# 921   Cc1ccc(NC(=O)c2ccnc(N3CCOCC3)c2)cc1N=c1cc[nH]c...           7.52
#
#         MolWt     LogP       QED
# 118   339.349  4.18800  0.608797
# 42    576.701  6.67222  0.200740
# 752   527.669  5.40832  0.351338
# 1404  515.828  4.90900  0.404159
# 1017  406.421  3.36640  0.545632
# ...       ...      ...       ...
# 236   402.523  4.95300  0.513182
# 537   597.720  4.46092  0.290574
# 336   518.847  7.62340  0.386913
# 873   547.625  6.50444  0.289316
# 921   491.596  2.76492  0.443289
#
# [1445 rows x 5 columns]

# %%
df.to_csv("Permuted Data",index=False)
