# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict, KFold
import numpy as np
import matplotlib.pyplot as plt

# %%
unsorted_fcv_rmse=[1.1012985087835148, 0.7711709375307846, 0.929036905006035, 0.7801589362328697, 0.7128731694469238, 0.7222645521062687, 0.6884808327233057, 0.6536754252459002, 0.6286032157335859]
sorted_fcv_rmse=[1.1473262082633755, 1.1404025197413539, 1.3967753961292508, 1.1015403076430743, 0.8691067459222744, 1.4678455118575136, 1.117501085305854, 0.9978017224219004, 0.8143118566940561]
cv_rmse=[0.6209263114839805, 0.7098346411496782, 0.5995178498568512, 0.5690266712675548, 0.6264857229783874, 0.596411928789979, 0.6710896013005199, 0.7274838396396194, 0.5914468148155495]

# %%
unsorted_fcv_rmse_druglike=[3.055100287204269, 2.4066724843630203, 2.5075450485081103, 1.1142516066582917, 1.1075003604663716, 0.991048486342662, 0.9484672300522762, 0.88586200869001, 0.8159120708478317]
sorted_fcv_rmse_druglike=[4.154486824422829, 3.3581429018425424, 3.1766542342376, 2.9079417607865032, 2.9566912581536795, 2.8298980560786187, 2.6936443030197044, 1.2582218827798568, 0.8205239733805111]
cv_rmse_druglike=[0.8400066307386704, 0.8623918022611688, 0.8437503938224139, 0.8307638700578791, 0.8142507199576186, 0.8139711375369454, 0.8730285411687563, 0.8835462334727415, 0.8330462382791437]

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest for most drug-like candidates')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
#Combined
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV Drug-Like')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV Drug-Like')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV Drug-Like')
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest for most drug-like candidates')
plt.legend(loc='upper right')

# Display the plot
plt.show()
