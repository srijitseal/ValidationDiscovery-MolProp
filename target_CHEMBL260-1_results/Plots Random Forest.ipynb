# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict, KFold
import numpy as np
import matplotlib.pyplot as plt

# %%
unsorted_fcv_rmse=[0.8014542250102804, 0.6385530063129292, 0.5206536830386377, 0.6216345593411853, 0.5735986866558649, 0.6468304286998747, 0.6769073132960307, 0.6706335743989493, 0.5136581222588618]
sorted_fcv_rmse=[0.7316926456101883, 0.6783392775759283, 0.9203447805119609, 0.9559651537393912, 0.5660540127910281, 0.9354951122690942, 0.6218435395009324, 0.7722658576686108, 0.9743037225372794]
cv_rmse=[0.6303803062248934, 0.5414178341273134, 0.5239637428386852, 0.5416497005401537, 0.5969471189788446, 0.516100752745166, 0.5043246837768967, 0.5508673221989726, 0.46146528377007956]

# %%
unsorted_fcv_rmse_druglike=[1.4665322478294336, 1.5655343428553754, 1.4817907049557169, 1.4936379812622653, 1.327493641172282, 1.2780907536646897, 1.1253142390052375, 0.8369842129326053, 0.944226412349166]
sorted_fcv_rmse_druglike=[1.678284110069733, 1.4534559789581172, 1.3461052421220916, 1.3873231299022497, 1.3367505071675487, 1.348099420877937, 1.3285926295287416, 1.1391891943987704, 0.9812244181277587]
cv_rmse_druglike=[0.8126169296081116, 1.0172437153936786, 0.9865095891697198, 1.0312444331740076, 0.7910618876919361, 0.8724017399529961, 0.9812641469205658, 1.0954886317174737, 0.9736493753049636]

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest for most drug-like candidates')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
#Combined
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV Drug-Like')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV Drug-Like')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV Drug-Like')
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Random Forest')
plt.legend(loc='upper right')

# Display the plot
plt.show()
