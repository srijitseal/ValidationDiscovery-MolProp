# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict, KFold
import numpy as np
import matplotlib.pyplot as plt

# %%
unsorted_fcv_rmse=[0.7520531944186433, 0.7096939533935883, 0.6069620059526082, 0.7202336127612008, 0.5941813041831148, 0.6273119467381392, 0.6097100442509032, 0.6393006764244588, 0.5562175472556138]
sorted_fcv_rmse=[0.7208841825693114, 0.678111952067937, 0.972172322604694, 0.8726494729702419, 0.6261359426612706, 1.0186554016125635, 0.7187183669970445, 0.7837740013445236, 0.855523136603924]
cv_rmse=[0.5366205096308806, 0.5615621873114123, 0.5917908125798834, 0.5016665715712123, 0.5595483107403972, 0.5159567120505646, 0.5130771520778298, 0.506258560438421, 0.5835814508424151]

# %%
unsorted_fcv_rmse_druglike=[1.1999138683719313, 1.097285196892165, 0.8523486907089246, 0.9395493673350699, 0.8463149555646651, 0.8049891719666776, 0.8991388508766105, 0.8608485610998072, 0.8636300359536361]
sorted_fcv_rmse_druglike=[1.5357768415660125, 1.46420812096332, 1.403539718462786, 1.6757693408680694, 1.576520361479255, 1.5745376660337604, 1.4738373373216849, 1.0896374629245746, 0.8613479406957555]
cv_rmse_druglike=[0.9906953071030156, 0.9024089429098487, 0.7900622153608334, 0.8663593842901505, 0.9220069591243205, 1.0702284074716613, 0.8000428796700927, 0.8811179551718065, 0.8801973610788325]

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('xgboost')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('xgboost for most drug-like candidates')
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
#Combined
plt.plot(np.arange(0,9),unsorted_fcv_rmse_druglike, label='Unsorted FCV Drug-Like')
plt.plot(np.arange(0,9), sorted_fcv_rmse_druglike, label='Sorted FCV Drug-Like')
plt.plot(np.arange(0,9), cv_rmse_druglike, label='CV Drug-Like')
plt.plot(np.arange(0,9),unsorted_fcv_rmse, label='Unsorted FCV')
plt.plot(np.arange(0,9), sorted_fcv_rmse, label='Sorted FCV')
plt.plot(np.arange(0,9), cv_rmse, label='CV')

# Adding labels and legend
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('xgboost for most drug-like candidates')
plt.legend(loc='upper right')

# Display the plot
plt.show()
