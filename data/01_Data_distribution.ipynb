# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=False)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# INFO: Pandarallel will run on 40 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
targets = ["target_CHEMBL240",
          "target_CHEMBL260",
          "target_CHEMBL279"]

# %%
data1 = pd.read_csv("target_CHEMBL240-1.IC50_ready.csv.gz")
data1["target"] = "target_CHEMBL240"

data2 = pd.read_csv("target_CHEMBL260-1.IC50_ready.csv.gz")
data2["target"] = "target_CHEMBL260"

data3 = pd.read_csv("target_CHEMBL279-1.IC50_ready.csv.gz")
data3["target"] = "target_CHEMBL279"

# %%
# Combine all datasets into a single DataFrame for easier plotting
df = pd.concat([data1, data2, data3])
df
# Out:
#                                     Standardized_SMILES  pchembl_value  \
# 0                     Brc1cncc(COCC2(c3ccccc3)CCNCC2)c1           4.82
# 1     C1=NC(c2c[nH]c(-c3cc4c([nH]c5ccccc54)c(C4CCCCC...           6.70
# 2     C1=NC(c2c[nH]c(-c3cc4c([nH]c5ccccc54)c(C4CCCCC...           6.47
# 3     C1=NC(c2c[nH]c(-c3cc4c([nH]c5ccccc54)c(C4CCOCC...           5.39
# 4     C1=NCCC(c2c[nH]c(-c3cc4c([nH]c5ccccc54)c(C4CCC...           7.05
# ...                                                 ...            ...
# 1636                  c1ccc(N=c2[nH]cc(-c3ccccc3)o2)cc1           5.92
# 1637       c1ccc(Oc2cccc(N=c3[nH]cc(-c4ccccc4)o3)c2)cc1           5.85
# 1638       c1cn(Cc2ccc3c(c2)-c2[nH]nc(-c4ccsc4)c2C3)cn1           6.83
# 1639  c1cnc(CCc2ccncc2)c(-c2n[nH]c(=NCc3ccc4c(c3)OCO...           7.07
# 1640  c1cnc(CCc2ccncc2)c(-c2n[nH]c(=Nc3cnc4ccccc4c3)...           6.42
#
#                 target
# 0     target_CHEMBL240
# 1     target_CHEMBL240
# 2     target_CHEMBL240
# ...

# %%
import joypy

# %%
# Set the style
sns.set(style="whitegrid")


# Create the figure with high DPI for a sharper display
plt.figure(figsize=(10, 6), dpi=300)  # Setting dpi here for display purposes

# Create the Joy Plot
fig, axes = joypy.joyplot(df, by='target', column='pchembl_value', 
                          figsize=(10, 5), overlap=3, color=['#1f77b4', '#ff7f0e', '#2ca02c'], 
                          alpha=0.5, linewidth=1)

# Add a title
plt.title('Joy Plot of pChEMBL Values for Three Datasets', fontsize=15)
plt.show()
